# %%
from twitterscraper import query_tweets
import datetime
import json, codecs

# %%
if __name__ == '__main__':
    list_of_tweets = query_tweets("Trump OR Clinton", 10)

    #print the retrieved tweets to the screen:
    for tweet in query_tweets("Trump OR Clinton", 10):
        print(tweet)

#     #Or save the retrieved tweets to file:
#     file = open(“output.txt”,”w”)
#     for tweet in query_tweets("Trump OR Clinton", 10):
#         file.write(tweet.encode('utf-8'))
#     file.close()
# Out:
# INFO: queries: ['Trump OR Clinton since:2006-03-21 until:2006-11-19', 'Trump OR Clinton since:2006-11-19 until:2007-07-21', 'Trump OR Clinton since:2007-07-21 until:2008-03-20', 'Trump OR Clinton since:2008-03-20 until:2008-11-19', 'Trump OR Clinton since:2008-11-19 until:2009-07-20', 'Trump OR Clinton since:2009-07-20 until:2010-03-21', 'Trump OR Clinton since:2010-03-21 until:2010-11-19', 'Trump OR Clinton since:2010-11-19 until:2011-07-21', 'Trump OR Clinton since:2011-07-21 until:2012-03-20', 'Trump OR Clinton since:2012-03-20 until:2012-11-19', 'Trump OR Clinton since:2012-11-19 until:2013-07-21', 'Trump OR Clinton since:2013-07-21 until:2014-03-21', 'Trump OR Clinton since:2014-03-21 until:2014-11-20', 'Trump OR Clinton since:2014-11-20 until:2015-07-21', 'Trump OR Clinton since:2015-07-21 until:2016-03-21', 'Trump OR Clinton since:2016-03-21 until:2016-11-19', 'Trump OR Clinton since:2016-11-19 until:2017-07-21', 'Trump OR Clinton since:2017-07-21 until:2018-03-21', 'Trump OR Clinton since:2018-03-21 until:2018-11-20', 'Trump OR Clinton since:2018-11-20 until:2019-07-22']
# INFO: Querying Trump OR Clinton since:2006-03-21 until:2006-11-19
# INFO: Querying Trump OR Clinton since:2007-07-21 until:2008-03-20
# INFO: Querying Trump OR Clinton since:2006-11-19 until:2007-07-21
# INFO: Querying Trump OR Clinton since:2008-03-20 until:2008-11-19
# INFO: Querying Trump OR Clinton since:2010-03-21 until:2010-11-19
# INFO: Querying Trump OR Clinton since:2008-11-19 until:2009-07-20
# INFO: Querying Trump OR Clinton since:2009-07-20 until:2010-03-21
# INFO: Querying Trump OR Clinton since:2011-07-21 until:2012-03-20
# INFO: Querying Trump OR Clinton since:2010-11-19 until:2011-07-21
# INFO: Querying Trump OR Clinton since:2012-03-20 until:2012-11-19
# INFO: Querying Trump OR Clinton since:2012-11-19 until:2013-07-21
# --- Logging error ---
# INFO: Querying Trump OR Clinton since:2013-07-21 until:2014-03-21
# --- Logging error ---
# --- Logging error ---
# INFO: Querying Trump OR Clinton since:2014-03-21 until:2014-11-20
# INFO: Querying Trump OR Clinton since:2014-11-20 until:2015-07-21
# INFO: Querying Trump OR Clinton since:2016-11-19 until:2017-07-21
# --- Logging error ---
# --- Logging error ---
# INFO: Querying Trump OR Clinton since:2016-03-21 until:2016-11-19
# INFO: Querying Trump OR Clinton since:2015-07-21 until:2016-03-21
# --- Logging error ---
# --- Logging error ---
# INFO: Querying Trump OR Clinton since:2017-07-21 until:2018-03-21
# INFO: Querying Trump OR Clinton since:2018-03-21 until:2018-11-20
# --- Logging error ---
# --- Logging error ---
# --- Logging error ---
# INFO: Querying Trump OR Clinton since:2018-11-20 until:2019-07-22
# --- Logging error ---
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# --- Logging error ---
# --- Logging error ---
# Traceback (most recent call last):
# --- Logging error ---
# --- Logging error ---
# Traceback (most recent call last):
# Traceback (most recent call last):
# --- Logging error ---
# --- Logging error ---
# --- Logging error ---
# --- Logging error ---
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 1034, in emit
#     msg = self.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 1034, in emit
#     msg = self.format(record)
# --- Logging error ---
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 1034, in emit
#     msg = self.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 1034, in emit
#     msg = self.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 1034, in emit
#     msg = self.format(record)
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 1034, in emit
#     msg = self.format(record)
# Traceback (most recent call last):
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 1034, in emit
#     msg = self.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 1034, in emit
#     msg = self.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 1034, in emit
#     msg = self.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 1034, in emit
#     msg = self.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 1034, in emit
#     msg = self.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 880, in format
#     return fmt.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 880, in format
#     return fmt.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 1034, in emit
#     msg = self.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 1034, in emit
#     msg = self.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 880, in format
#     return fmt.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 880, in format
#     return fmt.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 1034, in emit
#     msg = self.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 1034, in emit
#     msg = self.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 1034, in emit
#     msg = self.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 880, in format
#     return fmt.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 880, in format
#     return fmt.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 1034, in emit
#     msg = self.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 880, in format
#     return fmt.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 880, in format
#     return fmt.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 880, in format
#     return fmt.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 880, in format
#     return fmt.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 880, in format
#     return fmt.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 619, in format
#     record.message = record.getMessage()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 619, in format
#     record.message = record.getMessage()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 880, in format
#     return fmt.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 880, in format
#     return fmt.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 619, in format
#     record.message = record.getMessage()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 880, in format
#     return fmt.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 880, in format
#     return fmt.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 880, in format
#     return fmt.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 619, in format
#     record.message = record.getMessage()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 619, in format
#     record.message = record.getMessage()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 880, in format
#     return fmt.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 619, in format
#     record.message = record.getMessage()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 619, in format
#     record.message = record.getMessage()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 619, in format
#     record.message = record.getMessage()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 619, in format
#     record.message = record.getMessage()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 619, in format
#     record.message = record.getMessage()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 619, in format
#     record.message = record.getMessage()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 380, in getMessage
#     msg = msg % self.args
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 380, in getMessage
#     msg = msg % self.args
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 619, in format
#     record.message = record.getMessage()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 619, in format
#     record.message = record.getMessage()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 619, in format
#     record.message = record.getMessage()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 380, in getMessage
#     msg = msg % self.args
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 619, in format
#     record.message = record.getMessage()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 619, in format
#     record.message = record.getMessage()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 380, in getMessage
#     msg = msg % self.args
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 619, in format
#     record.message = record.getMessage()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 380, in getMessage
#     msg = msg % self.args
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 380, in getMessage
#     msg = msg % self.args
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 380, in getMessage
#     msg = msg % self.args
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 380, in getMessage
#     msg = msg % self.args
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 380, in getMessage
#     msg = msg % self.args
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 380, in getMessage
#     msg = msg % self.args
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 380, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# TypeError: not all arguments converted during string formatting
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 380, in getMessage
#     msg = msg % self.args
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 380, in getMessage
#     msg = msg % self.args
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 380, in getMessage
#     msg = msg % self.args
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 380, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 380, in getMessage
#     msg = msg % self.args
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 380, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# TypeError: not all arguments converted during string formatting
# TypeError: not all arguments converted during string formatting
# TypeError: not all arguments converted during string formatting
# TypeError: not all arguments converted during string formatting
# TypeError: not all arguments converted during string formatting
# TypeError: not all arguments converted during string formatting
# TypeError: not all arguments converted during string formatting
# Call stack:
# Call stack:
# TypeError: not all arguments converted during string formatting
# TypeError: not all arguments converted during string formatting
# TypeError: not all arguments converted during string formatting
# Call stack:
# TypeError: not all arguments converted during string formatting
# TypeError: not all arguments converted during string formatting
# TypeError: not all arguments converted during string formatting
# Call stack:
# Call stack:
# Call stack:
# Call stack:
# Call stack:
# Call stack:
# Call stack:
# Call stack:
# Call stack:
# Call stack:
# Call stack:
# Call stack:
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
# Call stack:
# Call stack:
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 1034, in emit
#     msg = self.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 1034, in emit
#     msg = self.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 1034, in emit
#     msg = self.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 880, in format
#     return fmt.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 880, in format
#     return fmt.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 880, in format
#     return fmt.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 619, in format
#     record.message = record.getMessage()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 619, in format
#     record.message = record.getMessage()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 619, in format
#     record.message = record.getMessage()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 539, in run_forever
#     self._run_once()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 380, in getMessage
#     msg = msg % self.args
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 380, in getMessage
#     msg = msg % self.args
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 380, in getMessage
#     msg = msg % self.args
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 539, in run_forever
#     self._run_once()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 539, in run_forever
#     self._run_once()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 539, in run_forever
#     self._run_once()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 539, in run_forever
#     self._run_once()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 539, in run_forever
#     self._run_once()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 539, in run_forever
#     self._run_once()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 539, in run_forever
#     self._run_once()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 539, in run_forever
#     self._run_once()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 1775, in _run_once
#     handle._run()
# TypeError: not all arguments converted during string formatting
# TypeError: not all arguments converted during string formatting
# TypeError: not all arguments converted during string formatting
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 539, in run_forever
#     self._run_once()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 539, in run_forever
#     self._run_once()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 1775, in _run_once
#     handle._run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 1775, in _run_once
#     handle._run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 539, in run_forever
#     self._run_once()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 1775, in _run_once
#     handle._run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 1775, in _run_once
#     handle._run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 1775, in _run_once
#     handle._run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 1775, in _run_once
#     handle._run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 1775, in _run_once
#     handle._run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 539, in run_forever
#     self._run_once()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 1775, in _run_once
#     handle._run()
# Call stack:
# Call stack:
# Call stack:
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 1775, in _run_once
#     handle._run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 539, in run_forever
#     self._run_once()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 539, in run_forever
#     self._run_once()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 539, in run_forever
#     self._run_once()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 1775, in _run_once
#     handle._run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 539, in run_forever
#     self._run_once()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 1775, in _run_once
#     handle._run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 1775, in _run_once
#     handle._run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 1775, in _run_once
#     handle._run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 1775, in _run_once
#     handle._run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 1775, in _run_once
#     handle._run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 1775, in _run_once
#     handle._run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 781, in inner
#     self.run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 781, in inner
#     self.run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 781, in inner
#     self.run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 781, in inner
#     self.run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 781, in inner
#     self.run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 781, in inner
#     self.run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 781, in inner
#     self.run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 781, in inner
#     self.run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 742, in run
#     yielded = self.gen.send(value)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 781, in inner
#     self.run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 781, in inner
#     self.run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 781, in inner
#     self.run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 742, in run
#     yielded = self.gen.send(value)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 742, in run
#     yielded = self.gen.send(value)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 781, in inner
#     self.run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 742, in run
#     yielded = self.gen.send(value)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 742, in run
#     yielded = self.gen.send(value)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 742, in run
#     yielded = self.gen.send(value)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 742, in run
#     yielded = self.gen.send(value)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 781, in inner
#     self.run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 742, in run
#     yielded = self.gen.send(value)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 742, in run
#     yielded = self.gen.send(value)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel/kernelbase.py", line 357, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 742, in run
#     yielded = self.gen.send(value)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 781, in inner
#     self.run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 781, in inner
#     self.run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 781, in inner
#     self.run()
# ...
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 176, in query_tweets_once
#     res = list(query_tweets_once_generator(*args, **kwargs))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 146, in query_tweets_once_generator
#     new_tweets, new_pos = query_single_page(query, lang, pos)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 176, in query_tweets_once
#     res = list(query_tweets_once_generator(*args, **kwargs))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 176, in query_tweets_once
#     res = list(query_tweets_once_generator(*args, **kwargs))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 146, in query_tweets_once_generator
#     new_tweets, new_pos = query_single_page(query, lang, pos)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/billiard/context.py", line 333, in _Popen
#     return Popen(process_obj)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/billiard/context.py", line 333, in _Popen
#     return Popen(process_obj)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 146, in query_tweets_once_generator
#     new_tweets, new_pos = query_single_page(query, lang, pos)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/billiard/context.py", line 333, in _Popen
#     return Popen(process_obj)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 62, in query_single_page
#     logger.info('Scraping tweets from {}', url)
# Process 'ForkPoolWorker-92' pid:22401 exited with 'signal 11 (SIGSEGV)'
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 176, in query_tweets_once
#     res = list(query_tweets_once_generator(*args, **kwargs))
# Process 'ForkPoolWorker-91' pid:22400 exited with 'signal 11 (SIGSEGV)'
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 62, in query_single_page
#     logger.info('Scraping tweets from {}', url)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 62, in query_single_page
#     logger.info('Scraping tweets from {}', url)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 62, in query_single_page
#     logger.info('Scraping tweets from {}', url)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 62, in query_single_page
#     logger.info('Scraping tweets from {}', url)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 62, in query_single_page
#     logger.info('Scraping tweets from {}', url)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 62, in query_single_page
#     logger.info('Scraping tweets from {}', url)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 146, in query_tweets_once_generator
#     new_tweets, new_pos = query_single_page(query, lang, pos)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 62, in query_single_page
#     logger.info('Scraping tweets from {}', url)
# Message: 'Scraping tweets from {}'
# Arguments: ('https://twitter.com/search?f=tweets&vertical=default&q=Trump%20OR%20Clinton%20since%3A2006-03-21%20until%3A2006-11-19&l=',)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 146, in query_tweets_once_generator
#     new_tweets, new_pos = query_single_page(query, lang, pos)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 62, in query_single_page
#     logger.info('Scraping tweets from {}', url)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 146, in query_tweets_once_generator
#     new_tweets, new_pos = query_single_page(query, lang, pos)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 146, in query_tweets_once_generator
#     new_tweets, new_pos = query_single_page(query, lang, pos)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 62, in query_single_page
#     logger.info('Scraping tweets from {}', url)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/billiard/popen_fork.py", line 24, in __init__
#     self._launch(process_obj)
# Process 'ForkPoolWorker-90' pid:22399 exited with 'signal 11 (SIGSEGV)'
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/billiard/popen_fork.py", line 24, in __init__
#     self._launch(process_obj)
# Process 'ForkPoolWorker-89' pid:22398 exited with 'signal 11 (SIGSEGV)'
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 62, in query_single_page
#     logger.info('Scraping tweets from {}', url)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/billiard/popen_fork.py", line 24, in __init__
#     self._launch(process_obj)
# Message: 'Scraping tweets from {}'
# Arguments: ('https://twitter.com/search?f=tweets&vertical=default&q=Trump%20OR%20Clinton%20since%3A2012-03-20%20until%3A2012-11-19&l=',)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 146, in query_tweets_once_generator
#     new_tweets, new_pos = query_single_page(query, lang, pos)
# Message: 'Scraping tweets from {}'
# Arguments: ('https://twitter.com/search?f=tweets&vertical=default&q=Trump%20OR%20Clinton%20since%3A2008-11-19%20until%3A2009-07-20&l=',)
# Message: 'Scraping tweets from {}'
# Arguments: ('https://twitter.com/search?f=tweets&vertical=default&q=Trump%20OR%20Clinton%20since%3A2010-03-21%20until%3A2010-11-19&l=',)
# Message: 'Scraping tweets from {}'
# Arguments: ('https://twitter.com/search?f=tweets&vertical=default&q=Trump%20OR%20Clinton%20since%3A2010-11-19%20until%3A2011-07-21&l=',)
# Message: 'Scraping tweets from {}'
# Arguments: ('https://twitter.com/search?f=tweets&vertical=default&q=Trump%20OR%20Clinton%20since%3A2012-11-19%20until%3A2013-07-21&l=',)
# Message: 'Scraping tweets from {}'
# Arguments: ('https://twitter.com/search?f=tweets&vertical=default&q=Trump%20OR%20Clinton%20since%3A2016-03-21%20until%3A2016-11-19&l=',)
# Message: 'Scraping tweets from {}'
# Arguments: ('https://twitter.com/search?f=tweets&vertical=default&q=Trump%20OR%20Clinton%20since%3A2014-03-21%20until%3A2014-11-20&l=',)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 62, in query_single_page
#     logger.info('Scraping tweets from {}', url)
# Message: 'Scraping tweets from {}'
# Arguments: ('https://twitter.com/search?f=tweets&vertical=default&q=Trump%20OR%20Clinton%20since%3A2011-07-21%20until%3A2012-03-20&l=',)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 62, in query_single_page
#     logger.info('Scraping tweets from {}', url)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 62, in query_single_page
#     logger.info('Scraping tweets from {}', url)
# Message: 'Scraping tweets from {}'
# Arguments: ('https://twitter.com/search?f=tweets&vertical=default&q=Trump%20OR%20Clinton%20since%3A2013-07-21%20until%3A2014-03-21&l=',)
# Process 'ForkPoolWorker-88' pid:22397 exited with 'signal 11 (SIGSEGV)'
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 62, in query_single_page
#     logger.info('Scraping tweets from {}', url)
# Process 'ForkPoolWorker-87' pid:22396 exited with 'signal 11 (SIGSEGV)'
# Message: 'Scraping tweets from {}'
# Arguments: ('https://twitter.com/search?f=tweets&vertical=default&q=Trump%20OR%20Clinton%20since%3A2015-07-21%20until%3A2016-03-21&l=',)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/billiard/popen_fork.py", line 79, in _launch
#     code = process_obj._bootstrap()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/billiard/popen_fork.py", line 79, in _launch
#     code = process_obj._bootstrap()
# Message: 'Scraping tweets from {}'
# Arguments: ('https://twitter.com/search?f=tweets&vertical=default&q=Trump%20OR%20Clinton%20since%3A2016-11-19%20until%3A2017-07-21&l=',)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/billiard/popen_fork.py", line 79, in _launch
#     code = process_obj._bootstrap()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 62, in query_single_page
#     logger.info('Scraping tweets from {}', url)
# Message: 'Scraping tweets from {}'
# Arguments: ('https://twitter.com/search?f=tweets&vertical=default&q=Trump%20OR%20Clinton%20since%3A2007-07-21%20until%3A2008-03-20&l=',)
# Message: 'Scraping tweets from {}'
# Arguments: ('https://twitter.com/search?f=tweets&vertical=default&q=Trump%20OR%20Clinton%20since%3A2009-07-20%20until%3A2010-03-21&l=',)
# Message: 'Scraping tweets from {}'
# Arguments: ('https://twitter.com/search?f=tweets&vertical=default&q=Trump%20OR%20Clinton%20since%3A2014-11-20%20until%3A2015-07-21&l=',)
# Message: 'Scraping tweets from {}'
# Arguments: ('https://twitter.com/search?f=tweets&vertical=default&q=Trump%20OR%20Clinton%20since%3A2006-11-19%20until%3A2007-07-21&l=',)
# Message: 'Scraping tweets from {}'
# Arguments: ('https://twitter.com/search?f=tweets&vertical=default&q=Trump%20OR%20Clinton%20since%3A2008-03-20%20until%3A2008-11-19&l=',)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/billiard/process.py", line 327, in _bootstrap
#     self.run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/billiard/process.py", line 327, in _bootstrap
#     self.run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/billiard/process.py", line 327, in _bootstrap
#     self.run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/billiard/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
# Process 'ForkPoolWorker-86' pid:22395 exited with 'signal 11 (SIGSEGV)'
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/billiard/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
# Process 'ForkPoolWorker-85' pid:22394 exited with 'signal 11 (SIGSEGV)'
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/billiard/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/billiard/pool.py", line 289, in __call__
#     sys.exit(self.workloop(pid=pid))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/billiard/pool.py", line 289, in __call__
#     sys.exit(self.workloop(pid=pid))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/billiard/pool.py", line 289, in __call__
#     sys.exit(self.workloop(pid=pid))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/billiard/pool.py", line 358, in workloop
#     result = (True, prepare_result(fun(*args, **kwargs)))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/billiard/pool.py", line 358, in workloop
#     result = (True, prepare_result(fun(*args, **kwargs)))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/billiard/pool.py", line 358, in workloop
#     result = (True, prepare_result(fun(*args, **kwargs)))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 176, in query_tweets_once
#     res = list(query_tweets_once_generator(*args, **kwargs))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 176, in query_tweets_once
#     res = list(query_tweets_once_generator(*args, **kwargs))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 176, in query_tweets_once
#     res = list(query_tweets_once_generator(*args, **kwargs))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 146, in query_tweets_once_generator
#     new_tweets, new_pos = query_single_page(query, lang, pos)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 146, in query_tweets_once_generator
#     new_tweets, new_pos = query_single_page(query, lang, pos)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 62, in query_single_page
#     logger.info('Scraping tweets from {}', url)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 146, in query_tweets_once_generator
#     new_tweets, new_pos = query_single_page(query, lang, pos)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 62, in query_single_page
#     logger.info('Scraping tweets from {}', url)
# Process 'ForkPoolWorker-84' pid:22393 exited with 'signal 11 (SIGSEGV)'
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 62, in query_single_page
#     logger.info('Scraping tweets from {}', url)
# Process 'ForkPoolWorker-83' pid:22392 exited with 'signal 11 (SIGSEGV)'
# Message: 'Scraping tweets from {}'
# Arguments: ('https://twitter.com/search?f=tweets&vertical=default&q=Trump%20OR%20Clinton%20since%3A2017-07-21%20until%3A2018-03-21&l=',)
# Message: 'Scraping tweets from {}'
# Arguments: ('https://twitter.com/search?f=tweets&vertical=default&q=Trump%20OR%20Clinton%20since%3A2018-11-20%20until%3A2019-07-22&l=',)
# Message: 'Scraping tweets from {}'
# Arguments: ('https://twitter.com/search?f=tweets&vertical=default&q=Trump%20OR%20Clinton%20since%3A2018-03-21%20until%3A2018-11-20&l=',)
# Process 'ForkPoolWorker-82' pid:22391 exited with 'signal 11 (SIGSEGV)'
# Process 'ForkPoolWorker-81' pid:22390 exited with 'signal 11 (SIGSEGV)'
# Process 'ForkPoolWorker-100' pid:22409 exited with 'signal 11 (SIGSEGV)'
# Process 'ForkPoolWorker-99' pid:22408 exited with 'signal 11 (SIGSEGV)'
# Process 'ForkPoolWorker-98' pid:22407 exited with 'signal 11 (SIGSEGV)'
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-10-e2f03cac572e> in <module>
#       1 if __name__ == '__main__':
# ----> 2     list_of_tweets = query_tweets("Trump OR Clinton", 10)
#       3
#       4     #print the retrieved tweets to the screen:
#       5     for tweet in query_tweets("Trump OR Clinton", 10):
#
# ~/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py in query_tweets(query, limit, begindate, enddate, poolsize, lang)
#     207         logger.info('queries: {}'.format(queries))
#     208         try:
# --> 209             for new_tweets in pool.imap_unordered(partial(query_tweets_once, limit=limit_per_pool, lang=lang), queries):
#     210                 all_tweets.extend(new_tweets)
#     211                 logger.info('Got {} tweets ({} new).'.format(
#
# ~/anaconda3/envs/dsi/lib/python3.7/site-packages/billiard/pool.py in next(self, timeout)
#    1921         if success:
#    1922             return value
# -> 1923         raise Exception(value)
#    1924
#    1925     __next__ = next                    # XXX
#
# Exception: Traceback (most recent call last):
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/billiard/pool.py", line 1226, in mark_as_worker_lost
#     human_status(exitcode)),
# billiard.exceptions.WorkerLostError: Worker exited prematurely: exitcode 0.

# %%
harvey = query_tweets("hurricaneharvey", limit = 50,
             begindate = datetime.date(2017, 8, 17),
             enddate = datetime.date(2017, 9, 10))
# Out:
# INFO: queries: ['hurricaneharvey since:2017-08-17 until:2017-08-18', 'hurricaneharvey since:2017-08-18 until:2017-08-19', 'hurricaneharvey since:2017-08-19 until:2017-08-20', 'hurricaneharvey since:2017-08-20 until:2017-08-21', 'hurricaneharvey since:2017-08-21 until:2017-08-23', 'hurricaneharvey since:2017-08-23 until:2017-08-24', 'hurricaneharvey since:2017-08-24 until:2017-08-25', 'hurricaneharvey since:2017-08-25 until:2017-08-26', 'hurricaneharvey since:2017-08-26 until:2017-08-27', 'hurricaneharvey since:2017-08-27 until:2017-08-29', 'hurricaneharvey since:2017-08-29 until:2017-08-30', 'hurricaneharvey since:2017-08-30 until:2017-08-31', 'hurricaneharvey since:2017-08-31 until:2017-09-01', 'hurricaneharvey since:2017-09-01 until:2017-09-02', 'hurricaneharvey since:2017-09-02 until:2017-09-04', 'hurricaneharvey since:2017-09-04 until:2017-09-05', 'hurricaneharvey since:2017-09-05 until:2017-09-06', 'hurricaneharvey since:2017-09-06 until:2017-09-07', 'hurricaneharvey since:2017-09-07 until:2017-09-08', 'hurricaneharvey since:2017-09-08 until:2017-09-10']
# INFO: Querying hurricaneharvey since:2017-08-17 until:2017-08-18
# INFO: Querying hurricaneharvey since:2017-08-19 until:2017-08-20
# INFO: Querying hurricaneharvey since:2017-08-20 until:2017-08-21
# INFO: Querying hurricaneharvey since:2017-08-18 until:2017-08-19
# INFO: Querying hurricaneharvey since:2017-08-21 until:2017-08-23
# INFO: Querying hurricaneharvey since:2017-08-23 until:2017-08-24
# INFO: Querying hurricaneharvey since:2017-08-24 until:2017-08-25
# INFO: Querying hurricaneharvey since:2017-08-25 until:2017-08-26
# INFO: Querying hurricaneharvey since:2017-08-26 until:2017-08-27
# --- Logging error ---
# --- Logging error ---
# --- Logging error ---
# --- Logging error ---
# --- Logging error ---
# --- Logging error ---
# --- Logging error ---
# --- Logging error ---
# --- Logging error ---
# INFO: Querying hurricaneharvey since:2017-08-30 until:2017-08-31
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# INFO: Querying hurricaneharvey since:2017-08-31 until:2017-09-01
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 1034, in emit
#     msg = self.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 1034, in emit
#     msg = self.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 1034, in emit
#     msg = self.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 1034, in emit
#     msg = self.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 1034, in emit
#     msg = self.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 1034, in emit
#     msg = self.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 1034, in emit
#     msg = self.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 1034, in emit
#     msg = self.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 1034, in emit
#     msg = self.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 880, in format
#     return fmt.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 880, in format
#     return fmt.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 880, in format
#     return fmt.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 880, in format
#     return fmt.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 880, in format
#     return fmt.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 880, in format
#     return fmt.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 880, in format
#     return fmt.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 880, in format
#     return fmt.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 880, in format
#     return fmt.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 619, in format
#     record.message = record.getMessage()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 619, in format
#     record.message = record.getMessage()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 619, in format
#     record.message = record.getMessage()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 619, in format
#     record.message = record.getMessage()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 619, in format
#     record.message = record.getMessage()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 619, in format
#     record.message = record.getMessage()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 619, in format
#     record.message = record.getMessage()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 619, in format
#     record.message = record.getMessage()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 619, in format
#     record.message = record.getMessage()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 380, in getMessage
#     msg = msg % self.args
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 380, in getMessage
#     msg = msg % self.args
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 380, in getMessage
#     msg = msg % self.args
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 380, in getMessage
#     msg = msg % self.args
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 380, in getMessage
#     msg = msg % self.args
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 380, in getMessage
#     msg = msg % self.args
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 380, in getMessage
#     msg = msg % self.args
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 380, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 380, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# TypeError: not all arguments converted during string formatting
# TypeError: not all arguments converted during string formatting
# TypeError: not all arguments converted during string formatting
# TypeError: not all arguments converted during string formatting
# TypeError: not all arguments converted during string formatting
# TypeError: not all arguments converted during string formatting
# Call stack:
# TypeError: not all arguments converted during string formatting
# Call stack:
# Call stack:
# Call stack:
# Call stack:
# Call stack:
# Call stack:
# Call stack:
# Call stack:
# INFO: Querying hurricaneharvey since:2017-08-27 until:2017-08-29
# INFO: Querying hurricaneharvey since:2017-08-29 until:2017-08-30
# INFO: Querying hurricaneharvey since:2017-09-01 until:2017-09-02
# --- Logging error ---
# --- Logging error ---
# --- Logging error ---
# INFO: Querying hurricaneharvey since:2017-09-02 until:2017-09-04
# --- Logging error ---
# --- Logging error ---
# Traceback (most recent call last):
# Traceback (most recent call last):
# --- Logging error ---
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 1034, in emit
#     msg = self.format(record)
# Traceback (most recent call last):
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 1034, in emit
#     msg = self.format(record)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 880, in format
#     return fmt.format(record)
# Traceback (most recent call last):
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 1034, in emit
#     msg = self.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 1034, in emit
#     msg = self.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 1034, in emit
#     msg = self.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 880, in format
#     return fmt.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 619, in format
#     record.message = record.getMessage()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 880, in format
#     return fmt.format(record)
# INFO: Querying hurricaneharvey since:2017-09-06 until:2017-09-07
# INFO: Querying hurricaneharvey since:2017-09-07 until:2017-09-08
# INFO: Querying hurricaneharvey since:2017-09-04 until:2017-09-05
# INFO: Querying hurricaneharvey since:2017-09-05 until:2017-09-06
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 880, in format
#     return fmt.format(record)
# INFO: Querying hurricaneharvey since:2017-09-08 until:2017-09-10
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 619, in format
#     record.message = record.getMessage()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 880, in format
#     return fmt.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 1034, in emit
#     msg = self.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 380, in getMessage
#     msg = msg % self.args
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 619, in format
#     record.message = record.getMessage()
# --- Logging error ---
# --- Logging error ---
# --- Logging error ---
# --- Logging error ---
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 619, in format
#     record.message = record.getMessage()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 380, in getMessage
#     msg = msg % self.args
# --- Logging error ---
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 619, in format
#     record.message = record.getMessage()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 880, in format
#     return fmt.format(record)
# TypeError: not all arguments converted during string formatting
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 380, in getMessage
#     msg = msg % self.args
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 380, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Traceback (most recent call last):
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 380, in getMessage
#     msg = msg % self.args
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 619, in format
#     record.message = record.getMessage()
# Traceback (most recent call last):
# Call stack:
# TypeError: not all arguments converted during string formatting
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 1034, in emit
#     msg = self.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 1034, in emit
#     msg = self.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 1034, in emit
#     msg = self.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 1034, in emit
#     msg = self.format(record)
# TypeError: not all arguments converted during string formatting
# Call stack:
# TypeError: not all arguments converted during string formatting
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 380, in getMessage
#     msg = msg % self.args
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 1034, in emit
#     msg = self.format(record)
# Call stack:
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 880, in format
#     return fmt.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 880, in format
#     return fmt.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 880, in format
#     return fmt.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 880, in format
#     return fmt.format(record)
# Call stack:
# Call stack:
# TypeError: not all arguments converted during string formatting
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 880, in format
#     return fmt.format(record)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 619, in format
#     record.message = record.getMessage()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 619, in format
#     record.message = record.getMessage()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 619, in format
#     record.message = record.getMessage()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 619, in format
#     record.message = record.getMessage()
# Call stack:
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 380, in getMessage
#     msg = msg % self.args
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 619, in format
#     record.message = record.getMessage()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 380, in getMessage
#     msg = msg % self.args
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 380, in getMessage
#     msg = msg % self.args
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 380, in getMessage
#     msg = msg % self.args
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
# TypeError: not all arguments converted during string formatting
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/logging/__init__.py", line 380, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
# TypeError: not all arguments converted during string formatting
# TypeError: not all arguments converted during string formatting
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
# Call stack:
# TypeError: not all arguments converted during string formatting
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
# Call stack:
# Call stack:
# Call stack:
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
# Call stack:
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 539, in run_forever
#     self._run_once()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 539, in run_forever
#     self._run_once()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 539, in run_forever
#     self._run_once()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 539, in run_forever
#     self._run_once()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 539, in run_forever
#     self._run_once()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 539, in run_forever
#     self._run_once()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 539, in run_forever
#     self._run_once()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 539, in run_forever
#     self._run_once()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 539, in run_forever
#     self._run_once()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 539, in run_forever
#     self._run_once()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 539, in run_forever
#     self._run_once()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 539, in run_forever
#     self._run_once()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 539, in run_forever
#     self._run_once()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 539, in run_forever
#     self._run_once()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 1775, in _run_once
#     handle._run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 1775, in _run_once
#     handle._run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 1775, in _run_once
#     handle._run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 1775, in _run_once
#     handle._run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 1775, in _run_once
#     handle._run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 1775, in _run_once
#     handle._run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 1775, in _run_once
#     handle._run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 1775, in _run_once
#     handle._run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 1775, in _run_once
#     handle._run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 1775, in _run_once
#     handle._run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 1775, in _run_once
#     handle._run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 1775, in _run_once
#     handle._run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 1775, in _run_once
#     handle._run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 1775, in _run_once
#     handle._run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 539, in run_forever
#     self._run_once()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 539, in run_forever
#     self._run_once()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 539, in run_forever
#     self._run_once()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 539, in run_forever
#     self._run_once()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 539, in run_forever
#     self._run_once()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/ipykernel/kernelapp.py", line 505, in start
#     self.io_loop.start()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 1775, in _run_once
#     handle._run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 1775, in _run_once
#     handle._run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 1775, in _run_once
#     handle._run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 781, in inner
#     self.run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 781, in inner
#     self.run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 781, in inner
#     self.run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 781, in inner
#     self.run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 781, in inner
#     self.run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 1775, in _run_once
#     handle._run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 781, in inner
#     self.run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 781, in inner
#     self.run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 781, in inner
#     self.run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 781, in inner
#     self.run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 781, in inner
#     self.run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/base_events.py", line 1775, in _run_once
#     handle._run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 781, in inner
#     self.run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 781, in inner
#     self.run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 781, in inner
#     self.run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/platform/asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 781, in inner
#     self.run()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 742, in run
#     yielded = self.gen.send(value)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 742, in run
#     yielded = self.gen.send(value)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 742, in run
#     yielded = self.gen.send(value)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 742, in run
#     yielded = self.gen.send(value)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 742, in run
#     yielded = self.gen.send(value)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 742, in run
#     yielded = self.gen.send(value)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 742, in run
#     yielded = self.gen.send(value)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 742, in run
#     yielded = self.gen.send(value)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 742, in run
#     yielded = self.gen.send(value)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 742, in run
#     yielded = self.gen.send(value)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/tornado/gen.py", line 742, in run
#     yielded = self.gen.send(value)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
# ...
#     new_tweets, new_pos = query_single_page(query, lang, pos)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 146, in query_tweets_once_generator
#     new_tweets, new_pos = query_single_page(query, lang, pos)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 146, in query_tweets_once_generator
#     new_tweets, new_pos = query_single_page(query, lang, pos)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 146, in query_tweets_once_generator
#     new_tweets, new_pos = query_single_page(query, lang, pos)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/billiard/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 146, in query_tweets_once_generator
#     new_tweets, new_pos = query_single_page(query, lang, pos)
# Process 'ForkPoolWorker-47' pid:22356 exited with 'signal 11 (SIGSEGV)'
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 146, in query_tweets_once_generator
#     new_tweets, new_pos = query_single_page(query, lang, pos)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/billiard/popen_fork.py", line 79, in _launch
#     code = process_obj._bootstrap()
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 146, in query_tweets_once_generator
#     new_tweets, new_pos = query_single_page(query, lang, pos)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 146, in query_tweets_once_generator
#     new_tweets, new_pos = query_single_page(query, lang, pos)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 62, in query_single_page
#     logger.info('Scraping tweets from {}', url)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/billiard/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 146, in query_tweets_once_generator
#     new_tweets, new_pos = query_single_page(query, lang, pos)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/billiard/pool.py", line 289, in __call__
#     sys.exit(self.workloop(pid=pid))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/billiard/pool.py", line 289, in __call__
#     sys.exit(self.workloop(pid=pid))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/billiard/pool.py", line 289, in __call__
#     sys.exit(self.workloop(pid=pid))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 146, in query_tweets_once_generator
#     new_tweets, new_pos = query_single_page(query, lang, pos)
# Process 'ForkPoolWorker-46' pid:22355 exited with 'signal 11 (SIGSEGV)'
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 146, in query_tweets_once_generator
#     new_tweets, new_pos = query_single_page(query, lang, pos)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 62, in query_single_page
#     logger.info('Scraping tweets from {}', url)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 62, in query_single_page
#     logger.info('Scraping tweets from {}', url)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 62, in query_single_page
#     logger.info('Scraping tweets from {}', url)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 62, in query_single_page
#     logger.info('Scraping tweets from {}', url)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 62, in query_single_page
#     logger.info('Scraping tweets from {}', url)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/billiard/pool.py", line 289, in __call__
#     sys.exit(self.workloop(pid=pid))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 62, in query_single_page
#     logger.info('Scraping tweets from {}', url)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 62, in query_single_page
#     logger.info('Scraping tweets from {}', url)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 62, in query_single_page
#     logger.info('Scraping tweets from {}', url)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/billiard/process.py", line 327, in _bootstrap
#     self.run()
# Process 'ForkPoolWorker-45' pid:22354 exited with 'signal 11 (SIGSEGV)'
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 62, in query_single_page
#     logger.info('Scraping tweets from {}', url)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/billiard/pool.py", line 289, in __call__
#     sys.exit(self.workloop(pid=pid))
# Message: 'Scraping tweets from {}'
# Arguments: ('https://twitter.com/search?f=tweets&vertical=default&q=hurricaneharvey%20since%3A2017-08-21%20until%3A2017-08-23&l=',)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 62, in query_single_page
#     logger.info('Scraping tweets from {}', url)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 62, in query_single_page
#     logger.info('Scraping tweets from {}', url)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 62, in query_single_page
#     logger.info('Scraping tweets from {}', url)
# Message: 'Scraping tweets from {}'
# Arguments: ('https://twitter.com/search?f=tweets&vertical=default&q=hurricaneharvey%20since%3A2017-08-29%20until%3A2017-08-30&l=',)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/billiard/pool.py", line 358, in workloop
#     result = (True, prepare_result(fun(*args, **kwargs)))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/billiard/pool.py", line 358, in workloop
#     result = (True, prepare_result(fun(*args, **kwargs)))
# Message: 'Scraping tweets from {}'
# Arguments: ('https://twitter.com/search?f=tweets&vertical=default&q=hurricaneharvey%20since%3A2017-08-19%20until%3A2017-08-20&l=',)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 62, in query_single_page
#     logger.info('Scraping tweets from {}', url)
# Process 'ForkPoolWorker-44' pid:22353 exited with 'signal 11 (SIGSEGV)'
# Message: 'Scraping tweets from {}'
# Arguments: ('https://twitter.com/search?f=tweets&vertical=default&q=hurricaneharvey%20since%3A2017-08-27%20until%3A2017-08-29&l=',)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/billiard/pool.py", line 358, in workloop
#     result = (True, prepare_result(fun(*args, **kwargs)))
# Message: 'Scraping tweets from {}'
# Arguments: ('https://twitter.com/search?f=tweets&vertical=default&q=hurricaneharvey%20since%3A2017-08-20%20until%3A2017-08-21&l=',)
# Message: 'Scraping tweets from {}'
# Arguments: ('https://twitter.com/search?f=tweets&vertical=default&q=hurricaneharvey%20since%3A2017-08-18%20until%3A2017-08-19&l=',)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/billiard/pool.py", line 358, in workloop
#     result = (True, prepare_result(fun(*args, **kwargs)))
# Message: 'Scraping tweets from {}'
# Arguments: ('https://twitter.com/search?f=tweets&vertical=default&q=hurricaneharvey%20since%3A2017-08-23%20until%3A2017-08-24&l=',)
# Message: 'Scraping tweets from {}'
# Arguments: ('https://twitter.com/search?f=tweets&vertical=default&q=hurricaneharvey%20since%3A2017-08-25%20until%3A2017-08-26&l=',)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/billiard/process.py", line 114, in run
#     self._target(*self._args, **self._kwargs)
# Message: 'Scraping tweets from {}'
# Arguments: ('https://twitter.com/search?f=tweets&vertical=default&q=hurricaneharvey%20since%3A2017-08-26%20until%3A2017-08-27&l=',)
# Message: 'Scraping tweets from {}'
# Arguments: ('https://twitter.com/search?f=tweets&vertical=default&q=hurricaneharvey%20since%3A2017-08-31%20until%3A2017-09-01&l=',)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/billiard/pool.py", line 358, in workloop
#     result = (True, prepare_result(fun(*args, **kwargs)))
# Process 'ForkPoolWorker-43' pid:22352 exited with 'signal 11 (SIGSEGV)'
# Message: 'Scraping tweets from {}'
# Arguments: ('https://twitter.com/search?f=tweets&vertical=default&q=hurricaneharvey%20since%3A2017-08-24%20until%3A2017-08-25&l=',)
# Message: 'Scraping tweets from {}'
# Arguments: ('https://twitter.com/search?f=tweets&vertical=default&q=hurricaneharvey%20since%3A2017-08-17%20until%3A2017-08-18&l=',)
# Message: 'Scraping tweets from {}'
# Arguments: ('https://twitter.com/search?f=tweets&vertical=default&q=hurricaneharvey%20since%3A2017-09-01%20until%3A2017-09-02&l=',)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 176, in query_tweets_once
#     res = list(query_tweets_once_generator(*args, **kwargs))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 176, in query_tweets_once
#     res = list(query_tweets_once_generator(*args, **kwargs))
# Message: 'Scraping tweets from {}'
# Arguments: ('https://twitter.com/search?f=tweets&vertical=default&q=hurricaneharvey%20since%3A2017-08-30%20until%3A2017-08-31&l=',)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 176, in query_tweets_once
#     res = list(query_tweets_once_generator(*args, **kwargs))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 176, in query_tweets_once
#     res = list(query_tweets_once_generator(*args, **kwargs))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/billiard/pool.py", line 289, in __call__
#     sys.exit(self.workloop(pid=pid))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 176, in query_tweets_once
#     res = list(query_tweets_once_generator(*args, **kwargs))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 146, in query_tweets_once_generator
#     new_tweets, new_pos = query_single_page(query, lang, pos)
# Process 'ForkPoolWorker-42' pid:22351 exited with 'signal 11 (SIGSEGV)'
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 146, in query_tweets_once_generator
#     new_tweets, new_pos = query_single_page(query, lang, pos)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 146, in query_tweets_once_generator
#     new_tweets, new_pos = query_single_page(query, lang, pos)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 146, in query_tweets_once_generator
#     new_tweets, new_pos = query_single_page(query, lang, pos)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 146, in query_tweets_once_generator
#     new_tweets, new_pos = query_single_page(query, lang, pos)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/billiard/pool.py", line 358, in workloop
#     result = (True, prepare_result(fun(*args, **kwargs)))
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 62, in query_single_page
#     logger.info('Scraping tweets from {}', url)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 62, in query_single_page
#     logger.info('Scraping tweets from {}', url)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 62, in query_single_page
#     logger.info('Scraping tweets from {}', url)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 62, in query_single_page
#     logger.info('Scraping tweets from {}', url)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 62, in query_single_page
#     logger.info('Scraping tweets from {}', url)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 176, in query_tweets_once
#     res = list(query_tweets_once_generator(*args, **kwargs))
# Process 'ForkPoolWorker-41' pid:22350 exited with 'signal 11 (SIGSEGV)'
# Message: 'Scraping tweets from {}'
# Arguments: ('https://twitter.com/search?f=tweets&vertical=default&q=hurricaneharvey%20since%3A2017-09-06%20until%3A2017-09-07&l=',)
# Message: 'Scraping tweets from {}'
# Arguments: ('https://twitter.com/search?f=tweets&vertical=default&q=hurricaneharvey%20since%3A2017-09-05%20until%3A2017-09-06&l=',)
# Message: 'Scraping tweets from {}'
# Arguments: ('https://twitter.com/search?f=tweets&vertical=default&q=hurricaneharvey%20since%3A2017-09-04%20until%3A2017-09-05&l=',)
# Message: 'Scraping tweets from {}'
# Arguments: ('https://twitter.com/search?f=tweets&vertical=default&q=hurricaneharvey%20since%3A2017-09-02%20until%3A2017-09-04&l=',)
# Message: 'Scraping tweets from {}'
# Arguments: ('https://twitter.com/search?f=tweets&vertical=default&q=hurricaneharvey%20since%3A2017-09-07%20until%3A2017-09-08&l=',)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 146, in query_tweets_once_generator
#     new_tweets, new_pos = query_single_page(query, lang, pos)
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py", line 62, in query_single_page
#     logger.info('Scraping tweets from {}', url)
# Message: 'Scraping tweets from {}'
# Arguments: ('https://twitter.com/search?f=tweets&vertical=default&q=hurricaneharvey%20since%3A2017-09-08%20until%3A2017-09-10&l=',)
# Process 'ForkPoolWorker-60' pid:22369 exited with 'signal 11 (SIGSEGV)'
# Process 'ForkPoolWorker-59' pid:22368 exited with 'signal 11 (SIGSEGV)'
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-7-4957ab915c46> in <module>
#       1 harvey = query_tweets("hurricaneharvey", limit = 50,
#       2              begindate = datetime.date(2017, 8, 17),
# ----> 3              enddate = datetime.date(2017, 9, 10))
#
# ~/anaconda3/envs/dsi/lib/python3.7/site-packages/twitterscraper/query.py in query_tweets(query, limit, begindate, enddate, poolsize, lang)
#     207         logger.info('queries: {}'.format(queries))
#     208         try:
# --> 209             for new_tweets in pool.imap_unordered(partial(query_tweets_once, limit=limit_per_pool, lang=lang), queries):
#     210                 all_tweets.extend(new_tweets)
#     211                 logger.info('Got {} tweets ({} new).'.format(
#
# ~/anaconda3/envs/dsi/lib/python3.7/site-packages/billiard/pool.py in next(self, timeout)
#    1921         if success:
#    1922             return value
# -> 1923         raise Exception(value)
#    1924
#    1925     __next__ = next                    # XXX
#
# Exception: Traceback (most recent call last):
#   File "/Users/macmedics/anaconda3/envs/dsi/lib/python3.7/site-packages/billiard/pool.py", line 1226, in mark_as_worker_lost
#     human_status(exitcode)),
# billiard.exceptions.WorkerLostError: Worker exited prematurely: exitcode 0.

# %%
harvey
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-9a20a5a8ef1d> in <module>
# ----> 1 harvey
#
# NameError: name 'harvey' is not defined
