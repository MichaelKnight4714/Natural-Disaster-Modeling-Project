# %%
import pandas as pd

# %%
data = pd.read_json('./data/cali_eq2017.json', lines = True)
data.head()
# Out:
#    contributors coordinates          created_at display_text_range  \
# 0           NaN        None 2019-07-07 17:53:14           [0, 137]
# 1           NaN        None 2019-07-07 19:20:37            [0, 59]
# 2           NaN        None 2019-07-07 16:09:48          [34, 306]
# 3           NaN        None 2019-07-07 17:26:15            [0, 57]
# 4           NaN        None 2019-07-07 19:12:19            [0, 55]
#
#                                             entities extended_entities  \
# 0  {'hashtags': [{'indices': [34, 45], 'text': 'e...               NaN
# 1  {'hashtags': [], 'symbols': [], 'urls': [{'dis...               NaN
# 2  {'hashtags': [], 'symbols': [], 'urls': [], 'u...               NaN
# 3  {'hashtags': [], 'symbols': [], 'urls': [], 'u...               NaN
# 4  {'hashtags': [], 'symbols': [], 'urls': [], 'u...               NaN
#
#    favorite_count  favorited  \
# 0               0      False
# 1               2      False
# 2               0      False
# ...

# %%
data
# Out:
#       contributors                                        coordinates  \
# 0              NaN                                               None
# 1              NaN                                               None
# 2              NaN                                               None
# 3              NaN                                               None
# 4              NaN                                               None
# 5              NaN                                               None
# 6              NaN                                               None
# 7              NaN                                               None
# 8              NaN                                               None
# 9              NaN  {'coordinates': [-70.72, 18.42], 'type': 'Point'}
# 10             NaN                                               None
# 11             NaN                                               None
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6763 entries, 0 to 6762
# Data columns (total 30 columns):
# contributors                 0 non-null float64
# coordinates                  237 non-null object
# created_at                   6763 non-null datetime64[ns]
# display_text_range           6763 non-null object
# entities                     6763 non-null object
# extended_entities            646 non-null object
# favorite_count               6763 non-null int64
# favorited                    6763 non-null bool
# full_text                    6763 non-null object
# geo                          237 non-null object
# id                           6763 non-null int64
# id_str                       6763 non-null int64
# in_reply_to_screen_name      1624 non-null object
# in_reply_to_status_id        1363 non-null float64
# in_reply_to_status_id_str    1363 non-null float64
# in_reply_to_user_id          1624 non-null float64
# in_reply_to_user_id_str      1624 non-null float64
# ...
